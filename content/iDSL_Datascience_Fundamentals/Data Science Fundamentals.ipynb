# %% [markdown]
# # Overview

# %% [markdown]
# ## Relevant Python Libraries

# %% [markdown]
# ### Numeric Computing & DataFrames

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# ### Plotting

# %% [markdown]
# **Matplotlib & Seaborn**

# %%
# %matplotlib

# %% [markdown]
# **Plotly**

# %% [markdown]
# ### General Requirements

# %% [markdown]
# ### Conveniant Libraries

# %% [markdown]
# TQDM
#
# https://pypi.org/project/tqdm/

# %%
from tqdm import tqdm_notebook

# %% [markdown]
# # Data

# %% [markdown]
# ## Download Data
#
# * https://www.backblaze.com/b2/hard-drive-test-data.html
#
# For this tutorial the data for 2017 will be used.
#
# * [docs_Q1_2017.zip](https://f001.backblazeb2.com/file/Backblaze-Hard-Drive-Data/docs_Q1_2017.zip) – 78 KB ZIP file, 106 KB on disk, 6 files
# * [data_Q1_2017.zip](https://f001.backblazeb2.com/file/Backblaze-Hard-Drive-Data/data_Q1_2017.zip) – 338.8 MB ZIP file, 1.74 GB on disk, 91 files.
#
#
# * [docs_Q2_2017.zip](https://f001.backblazeb2.com/file/Backblaze-Hard-Drive-Data/docs_Q2_2017.zip) – 78 KB ZIP file, 90 KB on disk, 5 files
# * [data_Q2_2017.zip](https://f001.backblazeb2.com/file/Backblaze-Hard-Drive-Data/data_Q2_2017.zip) – 386.7 MB ZIP file, 1.99 GB on disk, 91 files.
#
#
# * [docs_Q3_2017.zip](https://f001.backblazeb2.com/file/Backblaze-Hard-Drive-Data/docs_Q3_2017.zip) – 78 KB ZIP file, 106 KB on disk, 5 files
# * [data_Q3_2017.zip](https://f001.backblazeb2.com/file/Backblaze-Hard-Drive-Data/data_Q3_2017.zip) – 425.7 MB ZIP file, 2.13 GB on disk, 91 files.
#
#
# * [docs_Q4_2017.zip](https://f001.backblazeb2.com/file/Backblaze-Hard-Drive-Data/docs_Q4_2017.zip) – 78 KB ZIP file, 106 KB on disk, 5 files
# * [data_Q4_2017.zip](https://f001.backblazeb2.com/file/Backblaze-Hard-Drive-Data/data_Q4_2017.zip) – 465.2 MB ZIP file, 2.22 GB on disk, 92 files.
#
# ### Post-process Data archives
#
# The HDD-data for 2017 is provided in four achives. Extract the content of these archives into the same directories. This will result in a separate CSV-file for each day.

# %%
DATA_PATH = "D:/Data/PREDICTIVE_MAINTENANCE/Backblaze/2017/"

# %% [markdown]
# ### Loading Data

# %%
import os   # access OS functions
import glob # pathname matching

# %%
daywise_data = []

csv_files_to_import = glob.glob(os.path.join(DATA_PATH, "*.csv"))

for csv_filename in tqdm_notebook(csv_files_to_import, desc="Load CSV-Data"):
    
    # use Pandas CSV-reader
    data = pd.read_csv(csv_filename)
    
    # add this day to the list
    daywise_data.append(data)
# Out:
# HBox(children=(IntProgress(value=0, description='Load CSV-Data', max=365), HTML(value='')))

# %%
data
# Out:
#              date    serial_number                    model  capacity_bytes  \
# 0      2017-01-01   MJ0351YNG9Z0XA  Hitachi HDS5C3030ALA630   3000592982016
# 1      2017-01-01   MJ0351YNG9WJSA  Hitachi HDS5C3030ALA630   3000592982016
# 2      2017-01-01   PL1321LAG34XWH  Hitachi HDS5C4040ALE630   4000787030016
# 3      2017-01-01   MJ0351YNGABYAA  Hitachi HDS5C3030ALA630   3000592982016
# 4      2017-01-01         Z305B2QN              ST4000DM000   4000787030016
# 5      2017-01-01   PL2331LAGN2YTJ     HGST HMS5C4040BLE640   4000787030016
# 6      2017-01-01  WD-WMC4N2899475             WDC WD30EFRX   3000592982016
# 7      2017-01-01         Z302A0YH              ST4000DM000   4000787030016
# 8      2017-01-01         Z305BT0W              ST4000DM000   4000787030016
# 9      2017-01-01         ZA130TTW              ST8000DM002   8001563222016
# 10     2017-01-01   MJ0351YNG9Z7LA  Hitachi HDS5C3030ALA630   3000592982016
# 11     2017-01-01         ZA13YGB1              ST8000DM002   8001563222016
# 12     2017-01-01         Z302A0YE              ST4000DM000   4000787030016
# 13     2017-01-01         Z302PGH8              ST4000DM000   4000787030016
# 14     2017-01-01         Z3023VGH              ST4000DM000   4000787030016
# 15     2017-01-01   PL1311LAG2205A  Hitachi HDS5C4040ALE630   4000787030016
# 16     2017-01-01         Z300JA8E              ST4000DM000   4000787030016
# 17     2017-01-01         Z300KMM3              ST4000DM000   4000787030016
# 18     2017-01-01   PL2331LAHDW7KJ     HGST HMS5C4040BLE640   4000787030016
# 19     2017-01-01         Z303GWQQ              ST4000DM000   4000787030016
# 20     2017-01-01   MJ1311YNG7ESHA  Hitachi HDS5C3030ALA630   3000592982016
# 21     2017-01-01   PL2331LAGN3UVJ     HGST HMS5C4040BLE640   4000787030016
# 22     2017-01-01  WD-WX61A35NJXKT           WDC WD5000LPVX    500107862016
# 23     2017-01-01   PL2331LAHDUVVJ     HGST HMS5C4040BLE640   4000787030016
# 24     2017-01-01         ZA10JDYK              ST8000DM002   8001563222016
# 25     2017-01-01   PL1311LAG3A84H  Hitachi HDS5C4040ALE630   4000787030016
# 26     2017-01-01         Z300CMV1              ST4000DM000   4000787030016
# 27     2017-01-01   PL1331LAGSNKMH     HGST HMS5C4040ALE640   4000787030016
# 28     2017-01-01         S3010TR7              ST4000DM000   4000787030016
# 29     2017-01-01   PL1331LAHD252H     HGST HMS5C4040BLE640   4000787030016
# ...           ...              ...                      ...             ...
# 73623  2017-01-01   PL1321LAG33P5H  Hitachi HDS5C4040ALE630   4000787030016
# 73624  2017-01-01   PL1331LAGR6LZH     HGST HMS5C4040ALE640   4000787030016
# 73625  2017-01-01         Z303KECQ              ST4000DM000   4000787030016
# 73626  2017-01-01   PL2331LAHDW3GJ     HGST HMS5C4040BLE640   4000787030016
# 73627  2017-01-01   PL1331LAGRHPBH     HGST HMS5C4040ALE640   4000787030016
# 73628  2017-01-01         Z2A19GPP              ST3160316AS    160041885696
# 73629  2017-01-01         Z303MCKS              ST4000DM000   4000787030016
# 73630  2017-01-01   PL2331LAGRWX1J     HGST HMS5C4040ALE640   4000787030016
# 73631  2017-01-01         S301GPRW              ST4000DM000   4000787030016
# 73632  2017-01-01         Z4D01BW8              ST6000DX000   6001175126016
# 73633  2017-01-01         S300XCF3              ST4000DM000   4000787030016
# 73634  2017-01-01         S300XCF0              ST4000DM000   4000787030016
# 73635  2017-01-01   PL2331LAHAUARJ     HGST HMS5C4040BLE640   4000787030016
# 73636  2017-01-01     4593K19RFMYB      TOSHIBA MD04ABA400V   4000787030016
# 73637  2017-01-01   PL2331LAGM922J     HGST HMS5C4040BLE640   4000787030016
# 73638  2017-01-01         Z301EVVA              ST4000DM000   4000787030016
# 73639  2017-01-01         ZA10MCEG              ST8000DM002   8001563222016
# 73640  2017-01-01         Z3055EKF              ST4000DM000   4000787030016
# 73641  2017-01-01         Z4D09FH2              ST6000DX000   6001175126016
# 73642  2017-01-01   PL1331LAHDP4AH     HGST HMS5C4040BLE640   4000787030016
# 73643  2017-01-01  WD-WCC4N0396528             WDC WD30EFRX   3000592982016
# 73644  2017-01-01         ZA10MCEM              ST8000DM002   8001563222016
# 73645  2017-01-01         S300Z6K0              ST4000DM000   4000787030016
# 73646  2017-01-01         ZA10MCEJ              ST8000DM002   8001563222016
# 73647  2017-01-01         ZA10MCEH              ST8000DM002   8001563222016
# 73648  2017-01-01   PL1331LAHD1AWH     HGST HMS5C4040BLE640   4000787030016
# 73649  2017-01-01         Z3016V0V              ST4000DM000   4000787030016
# 73650  2017-01-01   MJ1323YNG1LZJC  Hitachi HDS5C3030ALA630   3000592982016
# 73651  2017-01-01         S300YQXW              ST4000DM000   4000787030016
# 73652  2017-01-01         Z30271GD              ST4000DM000   4000787030016
#
#        failure  smart_1_normalized  smart_1_raw  smart_2_normalized  \
# 0            0                 100            0               135.0
# 1            0                 100            0               136.0
# 2            0                 100            0               134.0
# 3            0                 100            0               136.0
# 4            0                 113     58173272                 NaN
# 5            0                 100            0               133.0
# 6            0                 200            0                 NaN
# 7            0                 114     75626904                 NaN
# 8            0                 112     48893128                 NaN
# 9            0                  83    199683560                 NaN
# 10           0                 100            0               136.0
# 11           0                  84    233028000                 NaN
# 12           0                 118    192617016                 NaN
# 13           0                 114     83211536                 NaN
# 14           0                 118    190444272                 NaN
# 15           0                 100            0               134.0
# 16           0                 117    119731104                 NaN
# 17           0                 119    221434504                 NaN
# 18           0                 100            0               134.0
# 19           0                 115     95382704                 NaN
# 20           0                 100            0               134.0
# 21           0                 100            0               133.0
# 22           0                 200            0                 NaN
# 23           0                 100            0               134.0
# 24           0                  79     79161328                 NaN
# 25           0                 100            0               135.0
# 26           0                 109     21830456                 NaN
# 27           0                 100            0               133.0
# 28           0                 111     33587480                 NaN
# 29           0                 100            0               133.0
# ...        ...                 ...          ...                 ...
# 73623        0                 100            0               135.0
# 73624        0                 100            0               134.0
# 73625        0                 117    152347328                 NaN
# 73626        0                 100            0               134.0
# 73627        0                 100            0               135.0
# 73628        0                 117    117480463                 NaN
# 73629        0                 117    120258944                 NaN
# 73630        0                 100            0               133.0
# 73631        0                 115     88888208                 NaN
# 73632        0                 117    135484290                 NaN
# 73633        0                 111     39809960                 NaN
# 73634        0                 119    225044368                 NaN
# 73635        0                 100            0               134.0
# 73636        0                 100            0               100.0
# 73637        0                 100            0               133.0
# 73638        0                 100      2989664                 NaN
# 73639        0                  81    139183960                 NaN
# 73640        0                 116    113707208                 NaN
# 73641        0                 118    192284473                 NaN
# 73642        0                 100            0               132.0
# 73643        0                 200            0                 NaN
# 73644        0                  78     64415248                 NaN
# 73645        0                 117    128650776                 NaN
# 73646        0                  80    108873336                 NaN
# 73647        0                  79     82466592                 NaN
# 73648        0                 100            0               134.0
# 73649        0                 109     23331776                 NaN
# 73650        0                 100            0               100.0
# 73651        0                 117    117741472                 NaN
# 73652        0                 108     15844008                 NaN
#
#        smart_2_raw  smart_3_normalized      ...        smart_250_normalized  \
# 0            108.0                 127      ...                         NaN
# 1            104.0                 126      ...                         NaN
# 2            101.0                 130      ...                         NaN
# 3            104.0                 137      ...                         NaN
# 4              NaN                  91      ...                         NaN
# 5            104.0                 100      ...                         NaN
# 6              NaN                 175      ...                         NaN
# 7              NaN                  92      ...                         NaN
# 8              NaN                  93      ...                         NaN
# 9              NaN                  98      ...                         NaN
# 10           104.0                 123      ...                         NaN
# 11             NaN                  96      ...                         NaN
# 12             NaN                  92      ...                         NaN
# 13             NaN                  92      ...                         NaN
# 14             NaN                  92      ...                         NaN
# 15           102.0                 130      ...                         NaN
# 16             NaN                  92      ...                         NaN
# 17             NaN                  91      ...                         NaN
# 18           103.0                 100      ...                         NaN
# 19             NaN                  95      ...                         NaN
# 20           110.0                 123      ...                         NaN
# 21           104.0                 100      ...                         NaN
# 22             NaN                 154      ...                         NaN
# 23           100.0                 100      ...                         NaN
# 24             NaN                  94      ...                         NaN
# 25            96.0                 128      ...                         NaN
# 26             NaN                  91      ...                         NaN
# 27           104.0                 100      ...                         NaN
# 28             NaN                  98      ...                         NaN
# 29           104.0                 100      ...                         NaN
# ...            ...                 ...      ...                         ...
# 73623         97.0                 100      ...                         NaN
# 73624        100.0                 100      ...                         NaN
# 73625          NaN                  96      ...                         NaN
# 73626        103.0                 100      ...                         NaN
# 73627         99.0                 100      ...                         NaN
# 73628          NaN                 100      ...                         NaN
# 73629          NaN                  97      ...                         NaN
# 73630        104.0                 126      ...                         NaN
# 73631          NaN                  98      ...                         NaN
# 73632          NaN                  88      ...                         NaN
# 73633          NaN                  97      ...                         NaN
# 73634          NaN                 100      ...                         NaN
# 73635        100.0                 100      ...                         NaN
# 73636          0.0                 100      ...                         NaN
# 73637        104.0                 126      ...                         NaN
# 73638          NaN                  91      ...                         NaN
# 73639          NaN                  96      ...                         NaN
# 73640          NaN                  93      ...                         NaN
# 73641          NaN                  97      ...                         NaN
# 73642        108.0                 100      ...                         NaN
# 73643          NaN                 176      ...                         NaN
# 73644          NaN                  84      ...                         NaN
# 73645          NaN                  98      ...                         NaN
# 73646          NaN                  90      ...                         NaN
# 73647          NaN                  96      ...                         NaN
# 73648        101.0                 100      ...                         NaN
# 73649          NaN                  91      ...                         NaN
# 73650          0.0                 124      ...                         NaN
# 73651          NaN                  96      ...                         NaN
# 73652          NaN                  91      ...                         NaN
#
#        smart_250_raw  smart_251_normalized  smart_251_raw  \
# 0                NaN                   NaN            NaN
# 1                NaN                   NaN            NaN
# 2                NaN                   NaN            NaN
# 3                NaN                   NaN            NaN
# 4                NaN                   NaN            NaN
# 5                NaN                   NaN            NaN
# 6                NaN                   NaN            NaN
# 7                NaN                   NaN            NaN
# 8                NaN                   NaN            NaN
# 9                NaN                   NaN            NaN
# 10               NaN                   NaN            NaN
# 11               NaN                   NaN            NaN
# 12               NaN                   NaN            NaN
# 13               NaN                   NaN            NaN
# 14               NaN                   NaN            NaN
# 15               NaN                   NaN            NaN
# 16               NaN                   NaN            NaN
# 17               NaN                   NaN            NaN
# 18               NaN                   NaN            NaN
# 19               NaN                   NaN            NaN
# 20               NaN                   NaN            NaN
# 21               NaN                   NaN            NaN
# 22               NaN                   NaN            NaN
# 23               NaN                   NaN            NaN
# 24               NaN                   NaN            NaN
# 25               NaN                   NaN            NaN
# 26               NaN                   NaN            NaN
# 27               NaN                   NaN            NaN
# 28               NaN                   NaN            NaN
# 29               NaN                   NaN            NaN
# ...              ...                   ...            ...
# 73623            NaN                   NaN            NaN
# 73624            NaN                   NaN            NaN
# 73625            NaN                   NaN            NaN
# 73626            NaN                   NaN            NaN
# 73627            NaN                   NaN            NaN
# 73628            NaN                   NaN            NaN
# 73629            NaN                   NaN            NaN
# 73630            NaN                   NaN            NaN
# 73631            NaN                   NaN            NaN
# 73632            NaN                   NaN            NaN
# 73633            NaN                   NaN            NaN
# 73634            NaN                   NaN            NaN
# 73635            NaN                   NaN            NaN
# 73636            NaN                   NaN            NaN
# 73637            NaN                   NaN            NaN
# 73638            NaN                   NaN            NaN
# 73639            NaN                   NaN            NaN
# 73640            NaN                   NaN            NaN
# 73641            NaN                   NaN            NaN
# 73642            NaN                   NaN            NaN
# 73643            NaN                   NaN            NaN
# 73644            NaN                   NaN            NaN
# 73645            NaN                   NaN            NaN
# 73646            NaN                   NaN            NaN
# 73647            NaN                   NaN            NaN
# 73648            NaN                   NaN            NaN
# 73649            NaN                   NaN            NaN
# 73650            NaN                   NaN            NaN
# 73651            NaN                   NaN            NaN
# 73652            NaN                   NaN            NaN
#
#        smart_252_normalized  smart_252_raw  smart_254_normalized  \
# 0                       NaN            NaN                   NaN
# 1                       NaN            NaN                   NaN
# 2                       NaN            NaN                   NaN
# 3                       NaN            NaN                   NaN
# 4                       NaN            NaN                   NaN
# 5                       NaN            NaN                   NaN
# 6                       NaN            NaN                   NaN
# 7                       NaN            NaN                   NaN
# 8                       NaN            NaN                   NaN
# 9                       NaN            NaN                   NaN
# 10                      NaN            NaN                   NaN
# 11                      NaN            NaN                   NaN
# 12                      NaN            NaN                   NaN
# 13                      NaN            NaN                   NaN
# 14                      NaN            NaN                   NaN
# 15                      NaN            NaN                   NaN
# 16                      NaN            NaN                   NaN
# 17                      NaN            NaN                   NaN
# 18                      NaN            NaN                   NaN
# 19                      NaN            NaN                   NaN
# 20                      NaN            NaN                   NaN
# 21                      NaN            NaN                   NaN
# 22                      NaN            NaN                   NaN
# 23                      NaN            NaN                   NaN
# 24                      NaN            NaN                   NaN
# 25                      NaN            NaN                   NaN
# 26                      NaN            NaN                   NaN
# 27                      NaN            NaN                   NaN
# 28                      NaN            NaN                   NaN
# 29                      NaN            NaN                   NaN
# ...                     ...            ...                   ...
# 73623                   NaN            NaN                   NaN
# 73624                   NaN            NaN                   NaN
# 73625                   NaN            NaN                   NaN
# 73626                   NaN            NaN                   NaN
# 73627                   NaN            NaN                   NaN
# 73628                   NaN            NaN                   NaN
# 73629                   NaN            NaN                   NaN
# 73630                   NaN            NaN                   NaN
# 73631                   NaN            NaN                   NaN
# 73632                   NaN            NaN                   NaN
# 73633                   NaN            NaN                   NaN
# 73634                   NaN            NaN                   NaN
# 73635                   NaN            NaN                   NaN
# 73636                   NaN            NaN                   NaN
# 73637                   NaN            NaN                   NaN
# 73638                   NaN            NaN                   NaN
# 73639                   NaN            NaN                   NaN
# 73640                   NaN            NaN                   NaN
# 73641                   NaN            NaN                   NaN
# 73642                   NaN            NaN                   NaN
# 73643                   NaN            NaN                   NaN
# 73644                   NaN            NaN                   NaN
# 73645                   NaN            NaN                   NaN
# 73646                   NaN            NaN                   NaN
# 73647                   NaN            NaN                   NaN
# 73648                   NaN            NaN                   NaN
# 73649                   NaN            NaN                   NaN
# 73650                   NaN            NaN                   NaN
# 73651                   NaN            NaN                   NaN
# 73652                   NaN            NaN                   NaN
#
#        smart_254_raw  smart_255_normalized  smart_255_raw
# 0                NaN                   NaN            NaN
# 1                NaN                   NaN            NaN
# 2                NaN                   NaN            NaN
# 3                NaN                   NaN            NaN
# 4                NaN                   NaN            NaN
# 5                NaN                   NaN            NaN
# 6                NaN                   NaN            NaN
# 7                NaN                   NaN            NaN
# 8                NaN                   NaN            NaN
# 9                NaN                   NaN            NaN
# 10               NaN                   NaN            NaN
# 11               NaN                   NaN            NaN
# 12               NaN                   NaN            NaN
# 13               NaN                   NaN            NaN
# 14               NaN                   NaN            NaN
# 15               NaN                   NaN            NaN
# 16               NaN                   NaN            NaN
# 17               NaN                   NaN            NaN
# 18               NaN                   NaN            NaN
# 19               NaN                   NaN            NaN
# 20               NaN                   NaN            NaN
# 21               NaN                   NaN            NaN
# 22               NaN                   NaN            NaN
# 23               NaN                   NaN            NaN
# 24               NaN                   NaN            NaN
# 25               NaN                   NaN            NaN
# 26               NaN                   NaN            NaN
# 27               NaN                   NaN            NaN
# 28               NaN                   NaN            NaN
# 29               NaN                   NaN            NaN
# ...              ...                   ...            ...
# 73623            NaN                   NaN            NaN
# 73624            NaN                   NaN            NaN
# 73625            NaN                   NaN            NaN
# 73626            NaN                   NaN            NaN
# 73627            NaN                   NaN            NaN
# 73628            NaN                   NaN            NaN
# 73629            NaN                   NaN            NaN
# 73630            NaN                   NaN            NaN
# 73631            NaN                   NaN            NaN
# 73632            NaN                   NaN            NaN
# 73633            NaN                   NaN            NaN
# 73634            NaN                   NaN            NaN
# 73635            NaN                   NaN            NaN
# 73636            NaN                   NaN            NaN
# 73637            NaN                   NaN            NaN
# 73638            NaN                   NaN            NaN
# 73639            NaN                   NaN            NaN
# 73640            NaN                   NaN            NaN
# 73641            NaN                   NaN            NaN
# 73642            NaN                   NaN            NaN
# 73643            NaN                   NaN            NaN
# 73644            NaN                   NaN            NaN
# 73645            NaN                   NaN            NaN
# 73646            NaN                   NaN            NaN
# 73647            NaN                   NaN            NaN
# 73648            NaN                   NaN            NaN
# 73649            NaN                   NaN            NaN
# 73650            NaN                   NaN            NaN
# 73651            NaN                   NaN            NaN
# 73652            NaN                   NaN            NaN
#
# [73653 rows x 95 columns]

# %% [markdown]
# ## Data Input

# %% [markdown]
# # Analysis / Inspection / Visualization

# %% [markdown]
# # Hypothesis Building

# %% [markdown]
# # Data Preparation

# %% [markdown]
# # Missing Values

# %% [markdown]
# # Experiment Design

# %% [markdown]
# # Machine Learning

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Parameter Tuning

# %% [markdown]
# # Comparing

# %% [markdown]
# # Significance Testing

# %% [markdown]
# # Interpretation
